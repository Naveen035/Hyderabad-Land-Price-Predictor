# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\jayas\OneDrive\Desktop\New folder\hyd_house_prediction\updated_land_data.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105 entries, 0 to 104
# Data columns (total 3 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Place Name             105 non-null    object
#  1   Price_in_2021 (sq.ft)  105 non-null    float64
#  2   Price_in_2020 (sq.ft)  105 non-null    float64
# dtypes: float64(2), object(1)
# memory usage: 2.6+ KB

# %%
df["Place Name"] = df["Place Name"].astype("category")

# %%
df.describe()
# Out:
#        Price_in_2021 (sq.ft)  Price_in_2020 (sq.ft)
# count             105.000000             105.000000
# mean            14112.647619           14399.209524
# std             20085.994237           26502.134164
# min               892.000000             903.000000
# 25%              4632.500000            4696.000000
# 50%              8266.000000            8000.000000
# 75%             15000.000000           14000.000000
# max            180000.000000          250000.000000

# %%
df.shape
# Out:
# (105, 3)

# %%
df["Price_in_2021 (sq.ft)"].nunique()
# Out:
# 70

# %%
df.isna().sum()
# Out:
# Place Name               0
# Price_in_2021 (sq.ft)    0
# Price_in_2020 (sq.ft)    0
# dtype: int64

# %%
sns.kdeplot(data = df,x = "Price_in_2020 (sq.ft)",y = "Price_in_2021 (sq.ft)")
# Out:
# <Axes: xlabel='Price_in_2020 (sq.ft)', ylabel='Price_in_2021 (sq.ft)'>

# %%
df1 = df[["Price_in_2021 (sq.ft)","Price_in_2020 (sq.ft)"]]
df1.corr()
# Out:
#                        Price_in_2021 (sq.ft)  Price_in_2020 (sq.ft)
# Price_in_2021 (sq.ft)               1.000000               0.976309
# Price_in_2020 (sq.ft)               0.976309               1.000000

# %%
df1.head()
# Out:
#    Price_in_2021 (sq.ft)  Price_in_2020 (sq.ft)
# 0                 3336.0                 3565.0
# 1                 7522.0                 7021.0
# 2                 8523.5                 8523.5
# 3                 3910.0                 3706.0
# 4                 5121.5                 4771.5

# %%
sns.heatmap(df1.corr(),annot = True,square = True,linecolor = "White",fmt = "-.2f")
# Out:
# <Axes: >

# %%
sns.catplot(data = df,x = "Price_in_2021 (sq.ft)",kind = "count",palette = "Set1")
# Out:
# C:\Users\jayas\AppData\Local\Temp\ipykernel_1764\1584211245.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(data = df,x = "Price_in_2021 (sq.ft)",kind = "count",palette = "Set1")

# %%
sns.boxplot(data = df,y = "Price_in_2020 (sq.ft)")
# Out:
# <Axes: ylabel='Price_in_2020 (sq.ft)'>

# %%
sns.distplot(x = df["Price_in_2020 (sq.ft)"],bins = 10)
# Out:
# C:\Users\jayas\AppData\Local\Temp\ipykernel_1764\3717846752.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x = df["Price_in_2020 (sq.ft)"],bins = 10)
# <Axes: ylabel='Density'>

# %%
sns.jointplot(x = "Price_in_2020 (sq.ft)",y = "Price_in_2021 (sq.ft)",data = df)
